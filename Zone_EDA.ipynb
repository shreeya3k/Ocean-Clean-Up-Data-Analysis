# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path = "/content/drive/My Drive/Ocean Cleanup Project/Data_Level5_BAH_OceanCleanup.csv"
data = pd.read_csv(path)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Cleanup ID                      Zone  ... Plastic Pieces Total Items Collected
# 0         86  Cuyahoga County, OH, USA  ...              0                   3.0
# 1         87   Fairfax County, VA, USA  ...              2                  10.0
# 2         92       Washington, DC, USA  ...              0                   4.0
# 3         93       Washington, DC, USA  ...              0                  14.0
# 4         94       Washington, DC, USA  ...              0                  14.0
#
# [5 rows x 61 columns]

# %%
zones = list(data['Zone'].unique())
zones.index('Linn County, OR, USA')
zones.pop(119)
zones
# Out:
# 900

# %%
#new1 = data.groupby('Zone')
for zone in zones[0:1]:
  new1 = data.groupby('Zone')
  new2 = new1.get_group(zone)
  new2= new2.drop(labels=['Cleanup Type','Cleanup ID', 'Zone', 'State', 'Country', 'GPS', 'Cleanup Date', 'Group Name', 'Adults', 'Children', 'People', 'Pounds', 'Miles', '# of bags', 'Total Items Collected'], axis =1)
  clean = new2.sum()
  clean = clean.to_frame()
  #new_row = pd.DataFrame()
  #new_row.append(zone)
  clean.insert(0,"Zone",zone)
  display(clean)
# Out:
#                                                                Zone      0
# Cigarette Butts                            Cuyahoga County, OH, USA  16326
# Food Wrappers (candy, chips, etc.)         Cuyahoga County, OH, USA   4018
# Take Out/Away Containers (Plastic)         Cuyahoga County, OH, USA    479
# Take Out/Away Containers (Foam)            Cuyahoga County, OH, USA    520
# Bottle Caps (Plastic)                      Cuyahoga County, OH, USA   8826
# Bottle Caps (Metal)                        Cuyahoga County, OH, USA   1016
# Lids (Plastic)                             Cuyahoga County, OH, USA   1645
# Straws, Stirrers                           Cuyahoga County, OH, USA   6944
# Forks, Knives, Spoons                      Cuyahoga County, OH, USA    838
# Beverage Bottles (Plastic)                 Cuyahoga County, OH, USA   1511
# Beverage Bottles (Glass)                   Cuyahoga County, OH, USA    553
# ...
